# %% [markdown]
# # Deployment using Streamlit
#
# ## Objective
#
# To deploy the trained XGBoost model as an interactive web application using Streamlit. The application enables users to enter engine sensor values and predict the Remaining Useful Life (RUL) along with a maintenance risk assessment.

# %%
import streamlit as st
import pandas as pd
import numpy as np
import joblib

# %%
model = joblib.load("../models/xgboost_model.pkl")
scaler = joblib.load("../models/scaler.pkl")
